# %%
# %matplotlib inline
import json
import matplotlib.pyplot as plt
import pandas as pd
from pandas.io.json import json_normalize
import time
import numpy as np
import seaborn as sns
import re
import os.path

# %%
path = "executions-bkp-gcloudeu-28-11.jsonl"
raw_data = pd.read_json(path, lines=True)
raw_data.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5d274d843299fa6236b8bc28'}
# 1  {'$oid': '5d274d853299fa6236b8bc29'}
# 2  {'$oid': '5d274e633299fa6236b8bc2a'}
# 3  {'$oid': '5d274e643299fa6236b8bc2b'}
# 4  {'$oid': '5d274e643299fa6236b8bc2c'}
#
#                                              payload               timestamp  \
# 0                               {'responseStamp': 1} 2019-07-11 14:53:56.866
# 1  {'name': 'Zombie Venom 09', 'source': '# 1 (ca... 2019-07-11 14:53:57.587
# 2                               {'responseStamp': 1} 2019-07-11 14:57:39.979
# 3  {'name': 'Zombie Venom 08', 'source': '# 1 (ca... 2019-07-11 14:57:40.069
# 4                               {'responseStamp': 2} 2019-07-11 14:57:40.085
#
#                                                topic
# 0  data/case/332f02b9-093e-4a2f-8d93-28022c275e8b...
# 1  data/case/332f02b9-093e-4a2f-8d93-28022c275e8b...
# 2  data/case/00f14675-854c-4c58-95eb-8dd414f525d3...
# 3  data/case/00f14675-854c-4c58-95eb-8dd414f525d3...
# 4                         data/theme/zombie.note/get

# %%
nl_experiment = raw_data.loc[lambda df: df.timestamp > '2019-11-28 7:30:00']

# %%
if os.path.exists('nl_experiment1.json'):
    print("Experiment data file already exists")
else:
    nl_experiment.to_json('nl_experiment1.json', orient='records')

# %%
def reconstruct_users_track(log):
    users_tracks = dict()
    for index, row in log.iterrows():
        payload = row.payload
        try:
            user = payload['userid']
            if user in users_tracks:
                users_tracks[user].append(row)
            else:
                users_tracks.update({user: [row]})
        except:
            pass
        
        try:
            user = payload['track']['userid'] 
            if user in users_tracks:
                users_tracks[user].append(row)
            else:
                users_tracks.update({user: [row]})
        except:
            pass

    return users_tracks

# %%
nl_experiment.head(10)
# Out:
#                                         _id  \
# 22113  {'$oid': '5ddf8655cd683579f92534ee'}
# 22114  {'$oid': '5ddf8655cd683579f92534ef'}
# 22115  {'$oid': '5ddf8655cd683579f92534f0'}
# 22116  {'$oid': '5ddf8655cd683579f92534f1'}
# 22117  {'$oid': '5ddf8655cd683579f92534f2'}
# 22118  {'$oid': '5ddf8655cd683579f92534f3'}
# 22119  {'$oid': '5ddf8656cd683579f92534f4'}
# 22120  {'$oid': '5ddf8656cd683579f92534f5'}
# 22121  {'$oid': '5ddf8656cd683579f92534f6'}
# 22122  {'$oid': '5ddf8656cd683579f92534f7'}
#
#                                                  payload  \
# 22113  {'email': 'A33@ds4h.org', 'password': 'a33', '...
# 22114  {'userid': 93, 'token': 'eyJhbGciOiJIUzI1NiIsI...
# 22115  {'filterBy': 'user', 'filter': 93, 'responseSt...
# 22116  [{'id': 'a46c78ec-9973-4792-a4ec-d9a9ef0e4978'...
# 22117                               {'responseStamp': 4}
# 22118  {'name': 'EKG-First', 'source': 'EKG-Descripti...
# 22119                                                 {}
# 22120  {'parameter': 'EKG first', 'track': {'userid':...
# 22121  {'track': {'userid': 93, 'caseid': 'a46c78ec-9...
# 22122  {'track': {'userid': 93, 'caseid': 'a46c78ec-9...
#
#                     timestamp  \
# 22113 2019-11-28 08:33:25.387
# 22114 2019-11-28 08:33:25.551
# 22115 2019-11-28 08:33:25.614
# 22116 2019-11-28 08:33:25.729
# 22117 2019-11-28 08:33:25.754
# 22118 2019-11-28 08:33:25.883
# 22119 2019-11-28 08:33:26.004
# 22120 2019-11-28 08:33:26.033
# 22121 2019-11-28 08:33:26.036
# 22122 2019-11-28 08:33:26.082
#
#                                                    topic
# 22113                                    data/user/login
# 22114                         data/user/login/response/2
# 22115                                   data/case/*/list
# 22116                        data/case/*/list/response/3
# 22117  data/case/a46c78ec-9973-4792-a4ec-d9a9ef0e4978...
# 22118  data/case/a46c78ec-9973-4792-a4ec-d9a9ef0e4978...
# 22119                                   knot/<</navigate
# 22120  2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...
# 22121  2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...
# 22122  2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...

# %%
nl_experiment
# Out:
#                                          _id  \
# 22113   {'$oid': '5ddf8655cd683579f92534ee'}
# 22114   {'$oid': '5ddf8655cd683579f92534ef'}
# 22115   {'$oid': '5ddf8655cd683579f92534f0'}
# 22116   {'$oid': '5ddf8655cd683579f92534f1'}
# 22117   {'$oid': '5ddf8655cd683579f92534f2'}
# 22118   {'$oid': '5ddf8655cd683579f92534f3'}
# 22119   {'$oid': '5ddf8656cd683579f92534f4'}
# 22120   {'$oid': '5ddf8656cd683579f92534f5'}
# 22121   {'$oid': '5ddf8656cd683579f92534f6'}
# 22122   {'$oid': '5ddf8656cd683579f92534f7'}
# 22123   {'$oid': '5ddf8656cd683579f92534f8'}
# 22124   {'$oid': '5ddf8656cd683579f92534f9'}
# 22125   {'$oid': '5ddf8658cd683579f92534fa'}
# 22126   {'$oid': '5ddf8658cd683579f92534fb'}
# 22127   {'$oid': '5ddf8658cd683579f92534fc'}
# 22128   {'$oid': '5ddf8658cd683579f92534fd'}
# 22129   {'$oid': '5ddf8658cd683579f92534fe'}
# 22130   {'$oid': '5ddf8658cd683579f92534ff'}
# 22131   {'$oid': '5ddf8658cd683579f9253500'}
# 22132   {'$oid': '5ddf8661cd683579f9253501'}
# 22133   {'$oid': '5ddf8661cd683579f9253502'}
# 22134   {'$oid': '5ddf8665cd683579f9253503'}
# 22135   {'$oid': '5ddf8665cd683579f9253504'}
# 22136   {'$oid': '5ddf8672cd683579f9253505'}
# 22137   {'$oid': '5ddf8672cd683579f9253506'}
# 22138   {'$oid': '5ddf8673cd683579f9253507'}
# 22139   {'$oid': '5ddf8673cd683579f9253508'}
# 22140   {'$oid': '5ddf8674cd683579f9253509'}
# 22141   {'$oid': '5ddf8674cd683579f925350a'}
# 22142   {'$oid': '5ddf8674cd683579f925350b'}
# ...                                      ...
# 104906  {'$oid': '5ddf8ee8cd683579f9267857'}
# 104907  {'$oid': '5ddf8ee8cd683579f9267858'}
# 104908  {'$oid': '5ddf8eeacd683579f9267859'}
# 104909  {'$oid': '5ddf8eedcd683579f926785a'}
# 104910  {'$oid': '5ddf8eedcd683579f926785b'}
# 104911  {'$oid': '5ddf8eedcd683579f926785c'}
# 104912  {'$oid': '5ddf8eedcd683579f926785d'}
# 104913  {'$oid': '5ddf8eedcd683579f926785e'}
# 104914  {'$oid': '5ddf8eedcd683579f926785f'}
# 104915  {'$oid': '5ddf8eeecd683579f9267860'}
# 104916  {'$oid': '5ddf8eeecd683579f9267861'}
# 104917  {'$oid': '5ddf8eeecd683579f9267862'}
# 104918  {'$oid': '5ddf8eeecd683579f9267863'}
# 104919  {'$oid': '5ddf8eeecd683579f9267864'}
# 104920  {'$oid': '5ddf8eeecd683579f9267865'}
# 104921  {'$oid': '5ddf9023cd683579f9267866'}
# 104922  {'$oid': '5ddf9024cd683579f9267867'}
# 104923  {'$oid': '5ddf9024cd683579f9267868'}
# 104924  {'$oid': '5ddf9024cd683579f9267869'}
# 104925  {'$oid': '5ddf9024cd683579f926786a'}
# 104926  {'$oid': '5ddf9024cd683579f926786b'}
# 104927  {'$oid': '5ddf9024cd683579f926786c'}
# 104928  {'$oid': '5ddf9024cd683579f926786d'}
# 104929  {'$oid': '5ddf9024cd683579f926786e'}
# 104930  {'$oid': '5ddf9024cd683579f926786f'}
# 104931  {'$oid': '5ddf9024cd683579f9267870'}
# 104932  {'$oid': '5ddf9024cd683579f9267871'}
# 104933  {'$oid': '5ddf9024cd683579f9267872'}
# 104934  {'$oid': '5ddf9025cd683579f9267873'}
# 104935  {'$oid': '5ddf9027cd683579f9267874'}
#
#                                                   payload  \
# 22113   {'email': 'A33@ds4h.org', 'password': 'a33', '...
# 22114   {'userid': 93, 'token': 'eyJhbGciOiJIUzI1NiIsI...
# 22115   {'filterBy': 'user', 'filter': 93, 'responseSt...
# 22116   [{'id': 'a46c78ec-9973-4792-a4ec-d9a9ef0e4978'...
# 22117                                {'responseStamp': 4}
# 22118   {'name': 'EKG-First', 'source': 'EKG-Descripti...
# 22119                                                  {}
# 22120   {'parameter': 'EKG first', 'track': {'userid':...
# 22121   {'track': {'userid': 93, 'caseid': 'a46c78ec-9...
# 22122   {'track': {'userid': 93, 'caseid': 'a46c78ec-9...
# 22123   {'track': {'userid': 93, 'caseid': 'a46c78ec-9...
# 22124                                {'responseStamp': 2}
# 22125   [{'id': '1a34ea2e-5432-47db-bd95-9e7b9608c44a'...
# 22126                                {'responseStamp': 3}
# 22127   {'name': 'Case-01', 'source': 'Description Cyc...
# 22128                                                  {}
# 22129   {'responseStamp': 6, 'track': {'userid': 93, '...
# 22130   {'content': '<div class="styt-main-frame">
#    ...
# 22131   {'track': {'userid': 93, 'caseid': '5c0cf92e-e...
# 22132   {'email': 's.altintas@mumc.nl', 'password': 'a...
# 22133                                                  {}
# 22134   {'email': 'marijnwiertsm@gmail.com', 'password...
# 22135                                                  {}
# 22136                                                  {}
# 22137   {'email': 'a55', 'password': '', 'responseStam...
# 22138   {'email': 'A42@ds4h.org', 'password': 'a42', '...
# 22139   {'userid': 102, 'token': 'eyJhbGciOiJIUzI1NiIs...
# 22140   [{'id': 'a67a30cf-a968-4744-a7fc-fc58a8bc4512'...
# 22141   {'filterBy': 'user', 'filter': 102, 'responseS...
# 22142   {'name': 'EKG-First', 'source': 'EKG-Descripti...
# ...                                                   ...
# 104906  {'content': 'test', 'track': {'userid': 1, 'ca...
# 104907  {'track': {'userid': 1, 'caseid': '64634e19-ea...
# 104908                               {'responseStamp': 2}
# 104909  [{'id': '1a34ea2e-5432-47db-bd95-9e7b9608c44a'...
# 104910                               {'responseStamp': 3}
# 104911  {'name': 'Cases-end', 'source': 'Final Message...
# 104912                                                 {}
# 104913  {'content': '', 'track': {'userid': 1, 'caseid...
# 104914  {'responseStamp': 6, 'track': {'userid': 1, 'c...
# 104915  {'content': '{knot}', 'track': {'userid': 1, '...
# 104916  {'responseStamp': 7, 'track': {'userid': 1, 'c...
# 104917  {'content': '{knot}', 'track': {'userid': 1, '...
# 104918  {'responseStamp': 8, 'track': {'userid': 1, 'c...
# 104919  {'content': '<div class="styt-main-frame">
#    ...
# 104920  {'track': {'userid': 1, 'caseid': '9b1651f3-de...
# 104921                               {'responseStamp': 2}
# 104922  [{'id': '1a34ea2e-5432-47db-bd95-9e7b9608c44a'...
# 104923                               {'responseStamp': 3}
# 104924  {'name': 'Cases-end', 'source': 'Final Message...
# 104925                                                 {}
# 104926  {'content': '', 'track': {'userid': 116, 'case...
# 104927  {'responseStamp': 6, 'track': {'userid': 116, ...
# 104928  {'content': '{knot}', 'track': {'userid': 116,...
# 104929  {'responseStamp': 7, 'track': {'userid': 116, ...
# 104930  {'content': '{knot}', 'track': {'userid': 116,...
# 104931  {'responseStamp': 8, 'track': {'userid': 116, ...
# 104932  {'content': '<div class="styt-main-frame">
#    ...
# 104933  {'track': {'userid': 116, 'caseid': '9b1651f3-...
# 104934                               {'responseStamp': 2}
# 104935  [{'id': '1a34ea2e-5432-47db-bd95-9e7b9608c44a'...
#
#                      timestamp  \
# 22113  2019-11-28 08:33:25.387
# 22114  2019-11-28 08:33:25.551
# 22115  2019-11-28 08:33:25.614
# 22116  2019-11-28 08:33:25.729
# 22117  2019-11-28 08:33:25.754
# 22118  2019-11-28 08:33:25.883
# 22119  2019-11-28 08:33:26.004
# 22120  2019-11-28 08:33:26.033
# 22121  2019-11-28 08:33:26.036
# 22122  2019-11-28 08:33:26.082
# 22123  2019-11-28 08:33:26.111
# 22124  2019-11-28 08:33:26.839
# 22125  2019-11-28 08:33:28.179
# 22126  2019-11-28 08:33:28.192
# 22127  2019-11-28 08:33:28.367
# 22128  2019-11-28 08:33:28.519
# 22129  2019-11-28 08:33:28.520
# 22130  2019-11-28 08:33:28.631
# 22131  2019-11-28 08:33:28.703
# 22132  2019-11-28 08:33:37.724
# 22133  2019-11-28 08:33:37.754
# 22134  2019-11-28 08:33:41.608
# 22135  2019-11-28 08:33:41.724
# 22136  2019-11-28 08:33:54.544
# 22137  2019-11-28 08:33:54.569
# 22138  2019-11-28 08:33:55.852
# 22139  2019-11-28 08:33:55.942
# 22140  2019-11-28 08:33:56.009
# 22141  2019-11-28 08:33:56.038
# 22142  2019-11-28 08:33:56.071
# ...                        ...
# 104906 2019-11-28 09:10:00.331
# 104907 2019-11-28 09:10:00.539
# 104908 2019-11-28 09:10:02.761
# 104909 2019-11-28 09:10:05.401
# 104910 2019-11-28 09:10:05.411
# 104911 2019-11-28 09:10:05.670
# 104912 2019-11-28 09:10:05.919
# 104913 2019-11-28 09:10:05.923
# 104914 2019-11-28 09:10:05.935
# 104915 2019-11-28 09:10:06.182
# 104916 2019-11-28 09:10:06.191
# 104917 2019-11-28 09:10:06.426
# 104918 2019-11-28 09:10:06.435
# 104919 2019-11-28 09:10:06.670
# 104920 2019-11-28 09:10:06.680
# 104921 2019-11-28 09:15:15.253
# 104922 2019-11-28 09:15:16.320
# 104923 2019-11-28 09:15:16.342
# 104924 2019-11-28 09:15:16.386
# 104925 2019-11-28 09:15:16.442
# 104926 2019-11-28 09:15:16.446
# 104927 2019-11-28 09:15:16.450
# 104928 2019-11-28 09:15:16.492
# 104929 2019-11-28 09:15:16.497
# 104930 2019-11-28 09:15:16.542
# 104931 2019-11-28 09:15:16.547
# 104932 2019-11-28 09:15:16.584
# 104933 2019-11-28 09:15:16.624
# 104934 2019-11-28 09:15:17.504
# 104935 2019-11-28 09:15:19.713
#
#                                                     topic
# 22113                                     data/user/login
# 22114                          data/user/login/response/2
# 22115                                    data/case/*/list
# 22116                         data/case/*/list/response/3
# 22117   data/case/a46c78ec-9973-4792-a4ec-d9a9ef0e4978...
# 22118   data/case/a46c78ec-9973-4792-a4ec-d9a9ef0e4978...
# 22119                                    knot/<</navigate
# 22120   2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...
# 22121   2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...
# 22122   2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...
# 22123   2019-11-28T08:33:25.342Z-980cae4f-15d1-9d08-11...
# 22124                                    data/case/*/list
# 22125                         data/case/*/list/response/2
# 22126   data/case/5c0cf92e-ebe3-4f83-bb3b-11846d0f3da8...
# 22127   data/case/5c0cf92e-ebe3-4f83-bb3b-11846d0f3da8...
# 22128                                    knot/<</navigate
# 22129   2019-11-28T08:33:27.837Z-22566a36-2735-ae78-fa...
# 22130   2019-11-28T08:33:27.837Z-22566a36-2735-ae78-fa...
# 22131   2019-11-28T08:33:27.837Z-22566a36-2735-ae78-fa...
# 22132                                     data/user/login
# 22133                          data/user/login/response/2
# 22134                                     data/user/login
# 22135                          data/user/login/response/2
# 22136                          data/user/login/response/2
# 22137                                     data/user/login
# 22138                                     data/user/login
# 22139                          data/user/login/response/2
# 22140                         data/case/*/list/response/3
# 22141                                    data/case/*/list
# 22142   data/case/a67a30cf-a968-4744-a7fc-fc58a8bc4512...
# ...                                                   ...
# 104906  2019-11-28T09:09:42.992Z-f48385f4-f5e6-7a15-98...
# 104907  2019-11-28T09:09:42.992Z-f48385f4-f5e6-7a15-98...
# 104908                                   data/case/*/list
# 104909                        data/case/*/list/response/2
# 104910  data/case/9b1651f3-dea3-443f-8faa-7d62d26610ec...
# 104911  data/case/9b1651f3-dea3-443f-8faa-7d62d26610ec...
# 104912                                   knot/<</navigate
# 104913  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104914  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104915  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104916  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104917  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104918  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104919  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104920  2019-11-28T09:10:05.816Z-d2466621-ceb5-189e-33...
# 104921                                   data/case/*/list
# 104922                        data/case/*/list/response/2
# 104923  data/case/9b1651f3-dea3-443f-8faa-7d62d26610ec...
# 104924  data/case/9b1651f3-dea3-443f-8faa-7d62d26610ec...
# 104925                                   knot/<</navigate
# 104926  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104927  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104928  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104929  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104930  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104931  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104932  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104933  2019-11-28T09:15:15.570Z-c73e9cbd-85e8-e63d-93...
# 104934                                   data/case/*/list
# 104935                        data/case/*/list/response/2
#
# [82823 rows x 4 columns]

# %%
users_track = reconstruct_users_track(nl_experiment)

# %%
print(sorted(users_track.keys()))
# Out:
# [1, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 115, 116]

# %%
def split_groups(users_track):
    group_A = dict()
    group_B = dict()
    
    for user in users_track.keys():
        for log in users_track[user]:
            try:
                if log['payload']['parameter'] == "Description first":
                    group_A[user] = users_track[user]
                if log['payload']['parameter'] == "EKG first":
                    group_B[user] = users_track[user]
            except:
                pass
    return group_A, group_B

# %%
group_A, group_B = split_groups(users_track)
print("Users Group A - Description First")
print(sorted(list(group_A.keys())))
print("Users Group B - EKG First")
print(sorted(list(group_B.keys())))
# Out:
# Users Group A - Description First
# [1, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 87]
# Users Group B - EKG First
# [86, 87, 88, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 115, 116]

# %%
# Manually adding user 89 whose don't have Group parameter
# group_B[89]=users_track[89]
#Deleting admin user and user in both groups
del(group_A[1])
del(group_A[87])
del(group_B[87])

# %%
print(len(list(group_A.keys())))
print(len(list(group_B.keys())))
# Out:
# 24
# 28

# %%
def users_answers(users_track):
    
    users_answers = dict()
    
    for user in users_track.keys():
        users_answers[user] = pd.DataFrame(columns=["Variable", "Answer", "CaseId"])

        for log in users_track[user]:
            if re.search('/var/[\w+.]+/set', log['topic']):
                var_topic = re.search('/var/[\w+.]+/set', log['topic']).group()
                answer = log['payload']['content']
                case_id = log['payload']['track']['caseid']
                elapsed_time = 0
                row = {"Variable": var_topic, "Answer": answer, "CaseId": case_id}
                users_answers[user] = users_answers[user].append(row, ignore_index=True)
                
    return users_answers

# %%
answers_groupA = users_answers(group_A)
answers_groupB = users_answers(group_B)

# %%
def clean_variables_track(answers_track, columns):
    
    users_answers_clean = dict()
    
    for user in answers_track.keys():
        cleaned_track = pd.DataFrame(columns=["Variable", "Answer", "CaseId"])
        group_track = answers_track[user].groupby(columns)
        
        for name, group in group_track:
            cleaned_track = cleaned_track.append(group_track.get_group(name).iloc[-1])
#             print(cleaned_track)
            
        users_answers_clean[user] = cleaned_track.sort_values(by=["CaseId","Variable"], ascending=False)
    
    return users_answers_clean

# %%
groupA_clean = clean_variables_track(answers_groupA, columns=["Variable", "CaseId"])
groupB_clean = clean_variables_track(answers_groupB, columns=["Variable", "CaseId"])

# %%
cases_dict = {"Case-01":"5c0cf92e-ebe3-4f83-bb3b-11846d0f3da8",
              "Case-02":"71cb08b0-aa66-402f-8d35-027e01bd541f",
              "Case-03":"1edff734-1090-4d44-bd52-963156b6b41d",
              "Case-07":"9c5b0ab8-33c8-4bcf-bcb4-d888327b870b",
              "Case-08":"28688ea2-f8d8-4664-80f6-0926720990fb",
              "Case-09":"ec4be4fd-4e48-4e84-ba8e-36c53b415698",
              "Case-12":"280fa4a7-1e79-4097-a961-7fda24d7d9bf",
              "Case-13":"7fbf35be-79fa-4087-94cd-ccc8030ac305",
              "Case-15":"a775bf21-b15c-44d1-a120-61611bc7960c",
              "Case-16":"b90056f9-e5e2-4281-bcfe-75ab62033b2b",
              "Case-17":"070e904b-fe21-4629-83b2-4f9ea49bccce",
              "Case-19":"64634e19-ea0a-4060-9656-1252b5d6acb5"
             }
cases_name = pd.DataFrame(cases_dict.items(), columns=["Case", "CaseId"])

# %%
topic_dict = {"EKG Hypothesis":"/var/EKG_Cycle.Generate_hypothesis.hypothesis/set",
              "EKG Confidence":"/var/EKG_Cycle.Generate_hypothesis.confidence/set",
              "Description Hypothesis":"/var/Description_Cycle.Generate_hypothesis.hypothesis/set",
              "Description Confidence":"/var/Description_Cycle.Generate_hypothesis.confidence/set"
             }
topic_names = pd.DataFrame(topic_dict.items(), columns=["Question", "Variable"])

# %%
def beautify_case_topic_name(users_track, topic_names, cases_name):
    
    for user in users_track.keys():
        df_merged = pd.merge(users_track[user],cases_name, on="CaseId", how="outer")
        df_merged = pd.merge(df_merged,topic_names, on="Variable", how="outer")
        df_merged.drop(columns=["Variable", "CaseId"], inplace=True)
        df_merged = df_merged[["Question","Answer","Case"]]
        df_merged = df_merged.sort_values(by=["Case","Question"], ascending=False)
        df_merged["Answer"] = df_merged["Answer"].str.lower()
        df_merged["Answer"] = df_merged["Answer"].str.strip()
        users_track[user] = df_merged
    
    return users_track

# %%
groupA_beauti = beautify_case_topic_name(groupA_clean, topic_names, cases_name)

# %%
groupB_beauti = beautify_case_topic_name(groupB_clean, topic_names, cases_name)

# %%
groupA_beauti[61]
# Out:
#                   Question                 Answer     Case
# 6           EKG Hypothesis                    acs  Case-19
# 18          EKG Confidence                     80  Case-19
# 30  Description Hypothesis                    acs  Case-19
# 42  Description Confidence                     72  Case-19
# 11          EKG Hypothesis                    acs  Case-17
# 23          EKG Confidence                     80  Case-17
# 35  Description Hypothesis       hyperventilation  Case-17
# 47  Description Confidence                     61  Case-17
# 1           EKG Hypothesis                acs 3vd  Case-16
# 13          EKG Confidence                     89  Case-16
# 25  Description Hypothesis                    acs  Case-16
# 37  Description Confidence                     80  Case-16
# 2           EKG Hypothesis                    acs  Case-15
# 14          EKG Confidence                     90  Case-15
# 26  Description Hypothesis                    acs  Case-15
# 38  Description Confidence                     89  Case-15
# 4           EKG Hypothesis                    acs  Case-13
# 16          EKG Confidence                     90  Case-13
# 28  Description Hypothesis                    acs  Case-13
# 40  Description Confidence                     81  Case-13
# 9           EKG Hypothesis  transient tachycardia  Case-12
# 21          EKG Confidence                     60  Case-12
# 33  Description Hypothesis                   afib  Case-12
# 45  Description Confidence                     50  Case-12
# 0           EKG Hypothesis                    acs  Case-09
# 12          EKG Confidence                     84  Case-09
# 24  Description Hypothesis                    acs  Case-09
# 36  Description Confidence                     75  Case-09
# 8           EKG Hypothesis                    acs  Case-08
# 20          EKG Confidence                     90  Case-08
# 32  Description Hypothesis                    acs  Case-08
# 44  Description Confidence                     70  Case-08
# 3           EKG Hypothesis           pericarditis  Case-07
# 15          EKG Confidence                     91  Case-07
# 27  Description Hypothesis           pericarditis  Case-07
# 39  Description Confidence                     50  Case-07
# 10          EKG Hypothesis          tendomyogenic  Case-03
# 22          EKG Confidence                     85  Case-03
# 34  Description Hypothesis          tendomyogenic  Case-03
# 46  Description Confidence                     85  Case-03
# 5           EKG Hypothesis       gastrointestinal  Case-02
# 17          EKG Confidence                     65  Case-02
# 29  Description Hypothesis       gastrointestinal  Case-02
# 41  Description Confidence                     85  Case-02
# 7           EKG Hypothesis                 nstemi  Case-01
# 19          EKG Confidence                     85  Case-01
# 31  Description Hypothesis                    acs  Case-01
# 43  Description Confidence                     60  Case-01

# %%
def all_answers_group(users_track, start_df=None):
    
    all_answers_group = pd.DataFrame(columns=["Question","Answer","Case"])
    
    if start_df is not None:
        all_answers_group = start_df
    
    for user in users_track:
        all_answers_group = pd.concat([all_answers_group, users_track[user]])
    
    return all_answers_group

# %%
all_answers_groupA = all_answers_group(groupA_beauti)

# %%
all_answers_groupA
# Out:
#                   Question                      Answer     Case
# 6           EKG Hypothesis                         iap  Case-19
# 18          EKG Confidence                          79  Case-19
# 30  Description Hypothesis                         iap  Case-19
# 42  Description Confidence                          76  Case-19
# 11          EKG Hypothesis                          ap  Case-17
# 23          EKG Confidence                          18  Case-17
# 35  Description Hypothesis            oesofagus spasme  Case-17
# 47  Description Confidence                          62  Case-17
# 1           EKG Hypothesis                          ap  Case-16
# 13          EKG Confidence                          68  Case-16
# 25  Description Hypothesis                          ap  Case-16
# 37  Description Confidence                          73  Case-16
# 2           EKG Hypothesis                         iap  Case-15
# 14          EKG Confidence                          59  Case-15
# 26  Description Hypothesis                         iap  Case-15
# 38  Description Confidence                          64  Case-15
# 4           EKG Hypothesis               tendomyalgeen  Case-13
# 16          EKG Confidence                          66  Case-13
# 28  Description Hypothesis               tendomyalgeen  Case-13
# 40  Description Confidence                          64  Case-13
# 9           EKG Hypothesis                         hvs  Case-12
# 21          EKG Confidence                          90  Case-12
# 33  Description Hypothesis                         hvs  Case-12
# 45  Description Confidence                          79  Case-12
# 0           EKG Hypothesis                   pneumonie  Case-09
# 12          EKG Confidence                          62  Case-09
# 24  Description Hypothesis                   pneumonie  Case-09
# 36  Description Confidence                          74  Case-09
# 8           EKG Hypothesis                          ap  Case-08
# 20          EKG Confidence                          77  Case-08
# ..                     ...                         ...      ...
# 28  Description Hypothesis  instabiele angina pectoris  Case-13
# 40  Description Confidence                          56  Case-13
# 9           EKG Hypothesis              myocardinfarct  Case-12
# 21          EKG Confidence                          26  Case-12
# 33  Description Hypothesis              myocardinfarct  Case-12
# 45  Description Confidence                          36  Case-12
# 0           EKG Hypothesis                     pyrosis  Case-09
# 12          EKG Confidence                          29  Case-09
# 24  Description Hypothesis                     pyrosis  Case-09
# 36  Description Confidence                          25  Case-09
# 8           EKG Hypothesis                      nstemi  Case-08
# 20          EKG Confidence                          95  Case-08
# 32  Description Hypothesis              myocardinfarct  Case-08
# 44  Description Confidence                          71  Case-08
# 3           EKG Hypothesis                pericarditis  Case-07
# 15          EKG Confidence                          88  Case-07
# 27  Description Hypothesis                pericarditis  Case-07
# 39  Description Confidence                          55  Case-07
# 10          EKG Hypothesis             hyperventilatie  Case-03
# 22          EKG Confidence                          79  Case-03
# 34  Description Hypothesis             hyperventilatie  Case-03
# 46  Description Confidence                          85  Case-03
# 5           EKG Hypothesis                          gi  Case-02
# 17          EKG Confidence                          72  Case-02
# 29  Description Hypothesis          gastro intestinaal  Case-02
# 41  Description Confidence                          52  Case-02
# 7           EKG Hypothesis                      nstemi  Case-01
# 19          EKG Confidence                          60  Case-01
# 31  Description Hypothesis                      nstemi  Case-01
# 43  Description Confidence                          50  Case-01
#
# [1134 rows x 3 columns]

# %%
all_answers_groupB = all_answers_group(groupB_beauti)

# %%
all_answers_groupB
# Out:
#                   Question                                             Answer  \
# 6           EKG Hypothesis                                           atypisch
# 18          EKG Confidence                                                 68
# 11          EKG Hypothesis                                           ischemie
# 23          EKG Confidence                                                 68
# 34  Description Hypothesis                                                 ap
# 45  Description Confidence                                                 59
# 1           EKG Hypothesis                                             nstemi
# 13          EKG Confidence                                                 73
# 25  Description Hypothesis                                                acs
# 36  Description Confidence                                                 86
# 2           EKG Hypothesis                                            normaal
# 14          EKG Confidence                                                 49
# 26  Description Hypothesis                                                iap
# 37  Description Confidence                                                 59
# 4           EKG Hypothesis                                       la dilatatie
# 16          EKG Confidence                                                 48
# 28  Description Hypothesis                                             nstemi
# 39  Description Confidence                                                 36
# 9           EKG Hypothesis                                           atypisch
# 21          EKG Confidence                                                 46
# 32  Description Hypothesis                                           atypisch
# 43  Description Confidence                                                 76
# 0           EKG Hypothesis                                        longembolie
# 12          EKG Confidence                                                 24
# 24  Description Hypothesis                                        longembolie
# 35  Description Confidence                                                 31
# 8           EKG Hypothesis                                            infarct
# 20          EKG Confidence                                                 70
# 31  Description Hypothesis                                                iap
# 42  Description Confidence                                                 74
# ..                     ...                                                ...
# 12  Description Hypothesis  inferolateraal negatieve ts en minimale st dep...
# 17  Description Confidence                                                 63
# 27                     NaN                                                NaN
# 26                     NaN                                                NaN
# 25                     NaN                                                NaN
# 24                     NaN                                                NaN
# 23                     NaN                                                NaN
# 22                     NaN                                                NaN
# 0           EKG Hypothesis                                   sinustachycardie
# 6           EKG Confidence                                                 49
# 4           EKG Hypothesis                                              stemi
# 10          EKG Confidence                                                 67
# 15  Description Hypothesis                                           ischemie
# 20  Description Confidence                                                 73
# 1           EKG Hypothesis                  st elevaties inferior en anterior
# 7           EKG Confidence                                                 49
# 12  Description Hypothesis                                       pericarditis
# 17  Description Confidence                                                 72
# 5           EKG Hypothesis  diffuus iets opgetrokken st segmenten, mogelij...
# 11          EKG Confidence                                                 18
# 16  Description Hypothesis                           atypische thoracale pijn
# 21  Description Confidence                                                 73
# 2           EKG Hypothesis  niet evident afwijkend ecg, vroege repolarisat...
# 8           EKG Confidence                                                 55
# 13  Description Hypothesis  atypische thoracale pijn, niet verdacht voor c...
# 18  Description Confidence                                                 81
# 3           EKG Hypothesis                        diffuus vlakke st segmenten
# 9           EKG Confidence                                                 38
# 14  Description Hypothesis                                      instabiele ap
# 19  Description Confidence                                                 23
#
#        Case
# 6   Case-19
# 18  Case-19
# 11  Case-17
# 23  Case-17
# 34  Case-17
# 45  Case-17
# 1   Case-16
# 13  Case-16
# 25  Case-16
# 36  Case-16
# 2   Case-15
# 14  Case-15
# 26  Case-15
# 37  Case-15
# 4   Case-13
# 16  Case-13
# 28  Case-13
# 39  Case-13
# 9   Case-12
# 21  Case-12
# 32  Case-12
# 43  Case-12
# 0   Case-09
# 12  Case-09
# 24  Case-09
# 35  Case-09
# 8   Case-08
# 20  Case-08
# 31  Case-08
# 42  Case-08
# ..      ...
# 12  Case-01
# 17  Case-01
# 27  Case-19
# 26  Case-17
# 25  Case-16
# 24  Case-15
# 23  Case-13
# 22  Case-12
# 0   Case-09
# 6   Case-09
# 4   Case-08
# 10  Case-08
# 15  Case-08
# 20  Case-08
# 1   Case-07
# 7   Case-07
# 12  Case-07
# 17  Case-07
# 5   Case-03
# 11  Case-03
# 16  Case-03
# 21  Case-03
# 2   Case-02
# 8   Case-02
# 13  Case-02
# 18  Case-02
# 3   Case-01
# 9   Case-01
# 14  Case-01
# 19  Case-01
#
# [1272 rows x 3 columns]

# %%
all_answers_experiment = all_answers_group(groupB_beauti,start_df=all_answers_groupA)

# %%
all_answers_experiment
# Out:
#                   Question                                             Answer  \
# 6           EKG Hypothesis                                                iap
# 18          EKG Confidence                                                 79
# 30  Description Hypothesis                                                iap
# 42  Description Confidence                                                 76
# 11          EKG Hypothesis                                                 ap
# 23          EKG Confidence                                                 18
# 35  Description Hypothesis                                   oesofagus spasme
# 47  Description Confidence                                                 62
# 1           EKG Hypothesis                                                 ap
# 13          EKG Confidence                                                 68
# 25  Description Hypothesis                                                 ap
# 37  Description Confidence                                                 73
# 2           EKG Hypothesis                                                iap
# 14          EKG Confidence                                                 59
# 26  Description Hypothesis                                                iap
# 38  Description Confidence                                                 64
# 4           EKG Hypothesis                                      tendomyalgeen
# 16          EKG Confidence                                                 66
# 28  Description Hypothesis                                      tendomyalgeen
# 40  Description Confidence                                                 64
# 9           EKG Hypothesis                                                hvs
# 21          EKG Confidence                                                 90
# 33  Description Hypothesis                                                hvs
# 45  Description Confidence                                                 79
# 0           EKG Hypothesis                                          pneumonie
# 12          EKG Confidence                                                 62
# 24  Description Hypothesis                                          pneumonie
# 36  Description Confidence                                                 74
# 8           EKG Hypothesis                                                 ap
# 20          EKG Confidence                                                 77
# ..                     ...                                                ...
# 12  Description Hypothesis  inferolateraal negatieve ts en minimale st dep...
# 17  Description Confidence                                                 63
# 27                     NaN                                                NaN
# 26                     NaN                                                NaN
# 25                     NaN                                                NaN
# 24                     NaN                                                NaN
# 23                     NaN                                                NaN
# 22                     NaN                                                NaN
# 0           EKG Hypothesis                                   sinustachycardie
# 6           EKG Confidence                                                 49
# 4           EKG Hypothesis                                              stemi
# 10          EKG Confidence                                                 67
# 15  Description Hypothesis                                           ischemie
# 20  Description Confidence                                                 73
# 1           EKG Hypothesis                  st elevaties inferior en anterior
# 7           EKG Confidence                                                 49
# 12  Description Hypothesis                                       pericarditis
# 17  Description Confidence                                                 72
# 5           EKG Hypothesis  diffuus iets opgetrokken st segmenten, mogelij...
# 11          EKG Confidence                                                 18
# 16  Description Hypothesis                           atypische thoracale pijn
# 21  Description Confidence                                                 73
# 2           EKG Hypothesis  niet evident afwijkend ecg, vroege repolarisat...
# 8           EKG Confidence                                                 55
# 13  Description Hypothesis  atypische thoracale pijn, niet verdacht voor c...
# 18  Description Confidence                                                 81
# 3           EKG Hypothesis                        diffuus vlakke st segmenten
# 9           EKG Confidence                                                 38
# 14  Description Hypothesis                                      instabiele ap
# 19  Description Confidence                                                 23
#
#        Case
# 6   Case-19
# 18  Case-19
# 30  Case-19
# 42  Case-19
# 11  Case-17
# 23  Case-17
# 35  Case-17
# 47  Case-17
# 1   Case-16
# 13  Case-16
# 25  Case-16
# 37  Case-16
# 2   Case-15
# 14  Case-15
# 26  Case-15
# 38  Case-15
# 4   Case-13
# 16  Case-13
# 28  Case-13
# 40  Case-13
# 9   Case-12
# 21  Case-12
# 33  Case-12
# 45  Case-12
# 0   Case-09
# 12  Case-09
# 24  Case-09
# 36  Case-09
# 8   Case-08
# 20  Case-08
# ..      ...
# 12  Case-01
# 17  Case-01
# 27  Case-19
# 26  Case-17
# 25  Case-16
# 24  Case-15
# 23  Case-13
# 22  Case-12
# 0   Case-09
# 6   Case-09
# 4   Case-08
# 10  Case-08
# 15  Case-08
# 20  Case-08
# 1   Case-07
# 7   Case-07
# 12  Case-07
# 17  Case-07
# 5   Case-03
# 11  Case-03
# 16  Case-03
# 21  Case-03
# 2   Case-02
# 8   Case-02
# 13  Case-02
# 18  Case-02
# 3   Case-01
# 9   Case-01
# 14  Case-01
# 19  Case-01
#
# [2406 rows x 3 columns]

# %%
hypothesis_groupA = all_answers_groupA[all_answers_groupA["Question"].str.contains("Hypothesis", na=False)]
hypothesis_groupB = all_answers_groupB[all_answers_groupB["Question"].str.contains("Hypothesis", na=False)]
all_hypothesis = all_answers_experiment[all_answers_experiment["Question"].str.contains("Hypothesis", na=False)]
confidence_groupA = all_answers_groupA[all_answers_groupA["Question"].str.contains("Confidence", na=False)]
confidence_groupB = all_answers_groupB[all_answers_groupB["Question"].str.contains("Confidence", na=False)]
all_confidence = all_answers_experiment[all_answers_experiment["Question"].str.contains("Confidence", na=False)]

# %%
answers_bycase_groupA_count = hypothesis_groupA.groupby("Case").apply(lambda x: x["Answer"].value_counts())

# %%
answers_bycase_groupA_count
# Out:
# Case
# Case-01  acs                                                        17
#          nstemi                                                     12
#          nste-acs                                                    4
#          reflux                                                      3
#          recidief infarct                                            1
#          acs-nstemi                                                  1
#          reflux dd acs                                               1
#          nstemi oud ecg?                                             1
#          zuurbranden                                                 1
#          angina pectoris                                             1
#          gastro-intestinaal dd acs                                   1
#          gastritis                                                   1
#          oud ecg? dd blijft gelijk                                   1
#          oud inferolateraal infarct, geen acute ischemie             1
#          acs-nsteni                                                  1
#          doorgemaakt ip infarct. st depressie lateraal.. dd maag     1
# Case-02  maagklachten                                                9
#          gastro intestinaal                                          5
#          gastritis                                                   3
#          acs                                                         3
#          gastrointestinal                                            2
#          pyrosis                                                     2
#          gastro-intestinaal probleem                                 2
#          castro oesofageaal                                          2
#          pericarditis                                                2
#          reflux                                                      2
#          gastro esofagaal                                            1
#          inferior cx infarct                                         1
#          reflux/maagklachten                                         1
#          gi                                                          1
#                                                                     ..
# Case-17  gastrointestinaal                                           1
#          oesofagus spasme                                            1
#          nste-acs                                                    1
#          tako-tsubo (cmp)                                            1
#          cardiale ischemie                                           1
#          iap                                                         1
#          niet cardiaal                                               1
#          hyperventilation                                            1
#          le                                                          1
#          nstemi                                                      1
#          lvh met strain en mogelijk subendocardiale ischemie         1
#          aspecifieke thoracale pijn                                  1
#          gastritis                                                   1
#          tako tsubo                                                  1
#          gastro intestinaal/spanning                                 1
#          reflux                                                      1
#          gastro intestinaal / spanning: ecg lvh                      1
#          lvh                                                         1
#          takotsubo cmp                                               1
# Case-19  acs                                                        22
#          iap                                                         8
#          nstemi                                                      4
#          nste-acs                                                    3
#          gastritis                                                   2
#          myocardinfarct                                              2
#          nstemi.. doorgemaakt posterior infarct op ecg..             1
#          psychogeen                                                  1
#          psychogeeb                                                  1
#          ip infarct doorgemaakt                                      1
#          slokdarmspasme                                              1
# Name: Answer, Length: 229, dtype: int64

# %%
answers_bycase_groupA_count.to_excel("hypothesis_groupDescription_count.xlsx")

# %%
answers_bycase_groupB_count = hypothesis_groupB.groupby("Case").apply(lambda x: x["Answer"].value_counts())
answers_bycase_groupB_count
# Out:
# Case
# Case-01  nstemi                                                                                                                17
#          acs                                                                                                                    8
#          inferolateraal negatieve ts en minimale st depressie (geen oud ecg), verdenking nstemi, stenose plcx restenose rca     2
#          stabiele angina pectoris                                                                                               2
#          doorgemaakt inferolateraal infarct                                                                                     2
#          doorgemaakt onderwandinfarct                                                                                           1
#          instabiele ap                                                                                                          1
#          doorgemaakt inferior infarct                                                                                           1
#          pyrosis                                                                                                                1
#          doorgemaakt onderwand infarct                                                                                          1
#          diffuus vlakke st segmenten                                                                                            1
#          oud infero-posterior infarct                                                                                           1
#          cardiac mimicking                                                                                                      1
#          mogelijk nstemi                                                                                                        1
#          angina pectoris of pyrosis                                                                                             1
#          doorgemaakt onderwandinfarct in                                                                                        1
#          ischemie inferolateraal                                                                                                1
#          doorgemaakt ischemie                                                                                                   1
#          inferolaterale ischemie                                                                                                1
#          history of myocardial infarction                                                                                       1
#          nstemi met inferolateraal neg t's                                                                                      1
#          doorgemaakt infero posterior infarct                                                                                   1
#          inferolateraal infarct doorgemaakt                                                                                     1
#          mogelijk nieuwe ischemie                                                                                               1
#          nstemi bij vg van oud inferoposterior infarct                                                                          1
#          doorgemaakt infarct                                                                                                    1
#          pyrosis/gerd, in het verleden doorgemaakt ipl infarct                                                                  1
#          restenose rca                                                                                                          1
#          ischemie                                                                                                               1
#          doorgemaakte ischemie ipl gebied                                                                                       1
#                                                                                                                                ..
# Case-17  stress                                                                                                                 1
#          functional                                                                                                             1
#          doorgemaakt inferolateraal infarct                                                                                     1
#          ap                                                                                                                     1
# Case-19  nstemi                                                                                                                15
#          acs                                                                                                                    4
#          normaal ecg                                                                                                            2
#          niet cardiaal                                                                                                          2
#          infectie                                                                                                               1
#          doorgemaakte ischemie inferior                                                                                         1
#          hypertensie                                                                                                            1
#          nste-acs                                                                                                               1
#          atypisch pob                                                                                                           1
#          doorgemaakt inferior infarct                                                                                           1
#          iap                                                                                                                    1
#          doorgemaakt posterior infarct                                                                                          1
#          viraal infect                                                                                                          1
#          sr                                                                                                                     1
#          atypisch                                                                                                               1
#          longembolie                                                                                                            1
#          preexcitatie                                                                                                           1
#          longprobleem                                                                                                           1
#          copd                                                                                                                   1
#          wpw?                                                                                                                   1
#          hypertension                                                                                                           1
#          stemi                                                                                                                  1
#          mogelijk doorgemaakt inferior ischemie                                                                                 1
#          angina pectoris                                                                                                        1
#          iap/nstemi                                                                                                             1
#          preexcitatie (v2)                                                                                                      1
# Name: Answer, Length: 314, dtype: int64

# %%
answers_bycase_groupB_count.to_excel("hypothesis_groupEKG_count.xlsx")

# %%
answers_bycase_count = all_hypothesis.groupby("Case").apply(lambda x: x["Answer"].value_counts())
answers_bycase_count
# Out:
# Case
# Case-01  nstemi                                                                                                                29
#          acs                                                                                                                   25
#          nste-acs                                                                                                               4
#          reflux                                                                                                                 3
#          stabiele angina pectoris                                                                                               2
#          inferolateraal negatieve ts en minimale st depressie (geen oud ecg), verdenking nstemi, stenose plcx restenose rca     2
#          doorgemaakt inferolateraal infarct                                                                                     2
#          ischemie                                                                                                               1
#          ischemie inferolateraal                                                                                                1
#          angina pectoris of pyrosis                                                                                             1
#          mogelijk nstemi                                                                                                        1
#          reflux dd acs                                                                                                          1
#          cardiac mimicking                                                                                                      1
#          oud infero-posterior infarct                                                                                           1
#          gastro-intestinaal dd acs                                                                                              1
#          doorgemaakt infero posterior infarct                                                                                   1
#          pyrosis                                                                                                                1
#          doorgemaakt onderwand infarct                                                                                          1
#          doorgemaakt inferior infarct                                                                                           1
#          instabiele ap                                                                                                          1
#          doorgemaakt onderwandinfarct                                                                                           1
#          zuurbranden                                                                                                            1
#          doorgemaakte ischemie ipl gebied                                                                                       1
#          doorgemaakt onderwandinfarct in                                                                                        1
#          oud ecg? dd blijft gelijk                                                                                              1
#          diffuus vlakke st segmenten                                                                                            1
#          nstemi bij vg van oud inferoposterior infarct                                                                          1
#          acs-nstemi                                                                                                             1
#          doorgemaakt ischemie                                                                                                   1
#          nstemi oud ecg?                                                                                                        1
#                                                                                                                                ..
# Case-19  nste-acs                                                                                                               4
#          gastritis                                                                                                              2
#          normaal ecg                                                                                                            2
#          myocardinfarct                                                                                                         2
#          niet cardiaal                                                                                                          2
#          hypertensie                                                                                                            1
#          psychogeen                                                                                                             1
#          sr                                                                                                                     1
#          psychogeeb                                                                                                             1
#          atypisch pob                                                                                                           1
#          nstemi.. doorgemaakt posterior infarct op ecg..                                                                        1
#          angina pectoris                                                                                                        1
#          doorgemaakt posterior infarct                                                                                          1
#          viraal infect                                                                                                          1
#          longembolie                                                                                                            1
#          infectie                                                                                                               1
#          doorgemaakte ischemie inferior                                                                                         1
#          longprobleem                                                                                                           1
#          iap/nstemi                                                                                                             1
#          wpw?                                                                                                                   1
#          copd                                                                                                                   1
#          slokdarmspasme                                                                                                         1
#          hypertension                                                                                                           1
#          doorgemaakt inferior infarct                                                                                           1
#          stemi                                                                                                                  1
#          mogelijk doorgemaakt inferior ischemie                                                                                 1
#          ip infarct doorgemaakt                                                                                                 1
#          atypisch                                                                                                               1
#          preexcitatie                                                                                                           1
#          preexcitatie (v2)                                                                                                      1
# Name: Answer, Length: 491, dtype: int64

# %%
answers_bycase_count.to_excel("hypothesis_experiment_count.xlsx")

# %%
answers_bycase_groupA = hypothesis_groupA.groupby("Case").apply(lambda x: x["Answer"].unique())
answers_bycase_groupB = hypothesis_groupB.groupby("Case").apply(lambda x: x["Answer"].unique())
answers_bycase = all_hypothesis.groupby("Case").apply(lambda x: x["Answer"].unique())

# %%
answers_bycase_groupA
# Out:
# Case
# Case-01    [acs, nste-acs, acs-nsteni, acs-nstemi, oud ec...
# Case-02    [gastro esofagaal, gastro-esofagaal, maagklach...
# Case-03    [tendomyalgeen, hyperventilatie, pericarditis ...
# Case-07    [pericarditis, pericaridits, costomyalgeen, te...
# Case-08    [ap, acs, nste-acs, iap, acs-nstemi, stemi pro...
# Case-09    [pneumonie, acs, stemi, nste-acs, stemi latera...
# Case-12    [hvs, costomyalgeen, acs, reflux, reflux/maagk...
# Case-13    [tendomyalgeen, acs, costomyalgeen, ap, ap-kla...
# Case-15    [iap, acs, nste-acs, infarct, acs-nstemi, acs ...
# Case-16    [ap, acs, nste-acs panischemie, iap, acs-nstem...
# Case-17    [ap, oesofagus spasme, acs, hyperventilatie, t...
# Case-19    [iap, acs, nste-acs, nstemi, gastritis, psycho...
# dtype: object

# %%
answers_bycase_groupA.to_excel("hypothesis_groupA_bycase.xlsx")

# %%
answers_bycase_groupB
# Out:
# Case
# Case-01    [nstemi, doorgemaakt inferolateraal infarct, a...
# Case-02    [ge reflux, inferior stemi, reflux, pericardit...
# Case-03    [lvh, hyperventilatie, stemi, costo-myalgeen, ...
# Case-07    [pericarditis, stemi, acs, inferoseptaal infar...
# Case-08    [infarct, iap, stemi septaal, nstemi, panische...
# Case-09    [longembolie, misschien stemi lateraal, doorge...
# Case-12    [atypisch, geen ischemie, nstemi, niet cardiaa...
# Case-13    [la dilatatie, nstemi, mitralisklepinsufficien...
# Case-15    [normaal, iap, normaal ecg, mogelijk inferior ...
# Case-16    [nstemi, acs, hoofdstamstenose, demand ischemi...
# Case-17    [ischemie, ap, nstemi, doorgemaakt ipl infarct...
# Case-19    [atypisch, doorgemaakte ischemie inferior, nst...
# dtype: object

# %%
answers_bycase_groupB.to_excel("hypothesis_groupB_bycase.xlsx")

# %%
answers_bycase
# Out:
# Case
# Case-01    [acs, nste-acs, acs-nsteni, acs-nstemi, oud ec...
# Case-02    [gastro esofagaal, gastro-esofagaal, maagklach...
# Case-03    [tendomyalgeen, hyperventilatie, pericarditis ...
# Case-07    [pericarditis, pericaridits, costomyalgeen, te...
# Case-08    [ap, acs, nste-acs, iap, acs-nstemi, stemi pro...
# Case-09    [pneumonie, acs, stemi, nste-acs, stemi latera...
# Case-12    [hvs, costomyalgeen, acs, reflux, reflux/maagk...
# Case-13    [tendomyalgeen, acs, costomyalgeen, ap, ap-kla...
# Case-15    [iap, acs, nste-acs, infarct, acs-nstemi, acs ...
# Case-16    [ap, acs, nste-acs panischemie, iap, acs-nstem...
# Case-17    [ap, oesofagus spasme, acs, hyperventilatie, t...
# Case-19    [iap, acs, nste-acs, nstemi, gastritis, psycho...
# dtype: object

# %%
answers_bycase.to_excel("hypothesis_experiment_bycase.xlsx")

# %%
all_confidence.astype({'Answer':'float64'})
# Out:
#                   Question  Answer     Case
# 18          EKG Confidence    79.0  Case-19
# 42  Description Confidence    76.0  Case-19
# 23          EKG Confidence    18.0  Case-17
# 47  Description Confidence    62.0  Case-17
# 13          EKG Confidence    68.0  Case-16
# 37  Description Confidence    73.0  Case-16
# 14          EKG Confidence    59.0  Case-15
# 38  Description Confidence    64.0  Case-15
# 16          EKG Confidence    66.0  Case-13
# 40  Description Confidence    64.0  Case-13
# 21          EKG Confidence    90.0  Case-12
# 45  Description Confidence    79.0  Case-12
# 12          EKG Confidence    62.0  Case-09
# 36  Description Confidence    74.0  Case-09
# 20          EKG Confidence    77.0  Case-08
# 44  Description Confidence    71.0  Case-08
# 15          EKG Confidence    98.0  Case-07
# 39  Description Confidence    66.0  Case-07
# 22          EKG Confidence    86.0  Case-03
# 46  Description Confidence    64.0  Case-03
# 17          EKG Confidence    73.0  Case-02
# 41  Description Confidence    77.0  Case-02
# 19          EKG Confidence    48.0  Case-01
# 43  Description Confidence    64.0  Case-01
# 17          EKG Confidence    55.0  Case-19
# 39  Description Confidence    59.0  Case-19
# 21          EKG Confidence    75.0  Case-17
# 43  Description Confidence    52.0  Case-17
# 12          EKG Confidence    65.0  Case-16
# 34  Description Confidence    53.0  Case-16
# ..                     ...     ...      ...
# 27  Description Confidence    64.0  Case-08
# 9           EKG Confidence    65.0  Case-07
# 24  Description Confidence    66.0  Case-07
# 15          EKG Confidence    35.0  Case-03
# 29  Description Confidence    84.0  Case-03
# 11          EKG Confidence    69.0  Case-02
# 25  Description Confidence    72.0  Case-02
# 12          EKG Confidence    68.0  Case-01
# 26  Description Confidence    77.0  Case-01
# 8           EKG Confidence    41.0  Case-08
# 18  Description Confidence    59.0  Case-08
# 5           EKG Confidence    63.0  Case-07
# 15  Description Confidence    69.0  Case-07
# 9           EKG Confidence    71.0  Case-03
# 19  Description Confidence    62.0  Case-03
# 6           EKG Confidence    70.0  Case-02
# 16  Description Confidence    63.0  Case-02
# 7           EKG Confidence    74.0  Case-01
# 17  Description Confidence    63.0  Case-01
# 6           EKG Confidence    49.0  Case-09
# 10          EKG Confidence    67.0  Case-08
# 20  Description Confidence    73.0  Case-08
# 7           EKG Confidence    49.0  Case-07
# 17  Description Confidence    72.0  Case-07
# 11          EKG Confidence    18.0  Case-03
# 21  Description Confidence    73.0  Case-03
# 8           EKG Confidence    55.0  Case-02
# 18  Description Confidence    81.0  Case-02
# 9           EKG Confidence    38.0  Case-01
# 19  Description Confidence    23.0  Case-01
#
# [1190 rows x 3 columns]

# %%
mean_std_all = all_confidence.groupby(["Case","Question"]).apply(lambda df: (df.Answer.astype('float64').mean(), df.Answer.astype('float64').std()))

# %%
mean_std_all
# Out:
# Case     Question
# Case-01  Description Confidence                 (58.25, 19.229139448284435)
#          EKG Confidence             (59.73076923076923, 18.151989449239693)
# Case-02  Description Confidence     (69.66666666666667, 15.367064347710224)
#          EKG Confidence              (63.17307692307692, 17.54961722821076)
# Case-03  Description Confidence      (67.6470588235294, 19.399818070705475)
#          EKG Confidence             (60.68627450980392, 23.559703050826787)
# Case-07  Description Confidence     (72.26923076923077, 18.985149391982606)
#          EKG Confidence              (69.42307692307692, 21.86890186493781)
# Case-08  Description Confidence                 (72.75, 14.215256923874598)
#          EKG Confidence              (68.73076923076923, 22.35113313319614)
# Case-09  Description Confidence                 (58.26, 22.642573229405254)
#          EKG Confidence              (55.80392156862745, 26.45147981330582)
# Case-12  Description Confidence     (56.91836734693877, 19.623366954023076)
#          EKG Confidence             (56.06122448979592, 23.522514182573847)
# Case-13  Description Confidence     (60.020833333333336, 19.03578889526905)
#          EKG Confidence             (54.93877551020408, 21.641403377231676)
# Case-15  Description Confidence     (70.52083333333333, 17.944346093897895)
#          EKG Confidence                          (57.5, 24.383461433712846)
# Case-16  Description Confidence     (64.41666666666667, 20.763955402852105)
#          EKG Confidence             (61.166666666666664, 22.29047438317431)
# Case-17  Description Confidence    (56.659574468085104, 22.038776691909554)
#          EKG Confidence              (57.8936170212766, 19.844212870729702)
# Case-19  Description Confidence     (60.577777777777776, 18.66996724066962)
#          EKG Confidence              (55.17391304347826, 22.50955781966218)
# dtype: object

# %%
mean_std_all.to_excel("Mean-Std-all.xlsx")

# %%
mean_std_groupA = confidence_groupA.groupby(["Case","Question"]).apply(lambda df: (df.Answer.astype('float64').mean(), df.Answer.astype('float64').std()))

# %%
mean_std_groupA
# Out:
# Case     Question
# Case-01  Description Confidence      (54.541666666666664, 20.3811062691313)
#          EKG Confidence                          (61.5, 17.433101946534382)
# Case-02  Description Confidence                  (68.25, 16.04138669057391)
#          EKG Confidence             (66.41666666666667, 15.021482201708054)
# Case-03  Description Confidence     (70.78260869565217, 16.681390071080926)
#          EKG Confidence              (73.26086956521739, 17.76671400350142)
# Case-07  Description Confidence     (65.70833333333333, 19.116301185493302)
#          EKG Confidence             (82.04166666666667, 18.355141837753745)
# Case-08  Description Confidence      (74.29166666666667, 12.21360313131532)
#          EKG Confidence              (83.95833333333333, 14.97382982774096)
# Case-09  Description Confidence    (58.458333333333336, 21.500210649456776)
#          EKG Confidence              (65.08333333333333, 27.29057277374076)
# Case-12  Description Confidence     (55.30434782608695, 20.912012169191822)
#          EKG Confidence             (53.78260869565217, 24.383221730860026)
# Case-13  Description Confidence     (59.82608695652174, 15.531938279537671)
#          EKG Confidence             (62.65217391304348, 21.827023900019352)
# Case-15  Description Confidence                 (72.75, 14.450063938477468)
#          EKG Confidence             (58.833333333333336, 22.30746934113767)
# Case-16  Description Confidence     (58.95652173913044, 19.898556962000047)
#          EKG Confidence             (68.78260869565217, 20.484931317121706)
# Case-17  Description Confidence                  (56.0, 23.196786611315567)
#          EKG Confidence             (58.65217391304348, 20.477501391554263)
# Case-19  Description Confidence       (64.78260869565217, 16.4370881123345)
#          EKG Confidence             (63.56521739130435, 19.301027026269217)
# dtype: object

# %%
mean_std_groupA.to_excel("Mean-Std-GroupA.xlsx")

# %%
mean_std_groupB = confidence_groupB.groupby(["Case","Question"]).apply(lambda df: (df.Answer.astype('float64').mean(), df.Answer.astype('float64').std()))

# %%
mean_std_groupB
# Out:
# Case     Question
# Case-01  Description Confidence     (61.42857142857143, 17.941114733583245)
#          EKG Confidence            (58.214285714285715, 18.929414975713097)
# Case-02  Description Confidence     (70.92592592592592, 14.932993738507427)
#          EKG Confidence            (60.392857142857146, 19.291793084710413)
# Case-03  Description Confidence      (65.07142857142857, 21.32973680000932)
#          EKG Confidence             (50.357142857142854, 22.92049751530726)
# Case-07  Description Confidence     (77.89285714285714, 17.276272072399667)
#          EKG Confidence             (58.607142857142854, 18.80177155899448)
# Case-08  Description Confidence     (71.42857142857143, 15.833458646120647)
#          EKG Confidence             (55.67857142857143, 19.231635918606095)
# Case-09  Description Confidence     (58.07692307692308, 24.073093821813725)
#          EKG Confidence             (47.55555555555556, 23.163853361738038)
# Case-12  Description Confidence      (58.34615384615385, 18.70816358212063)
#          EKG Confidence              (58.07692307692308, 23.02506994894578)
# Case-13  Description Confidence                  (60.2, 22.100150829047898)
#          EKG Confidence              (48.11538461538461, 19.41201055651253)
# Case-15  Description Confidence      (68.29166666666667, 20.94813298034741)
#          EKG Confidence            (56.166666666666664, 26.713726591507168)
# Case-16  Description Confidence                 (69.44, 20.652037833266395)
#          EKG Confidence                         (54.16, 21.946298093300385)
# Case-17  Description Confidence     (57.291666666666664, 21.35105977751897)
#          EKG Confidence             (57.166666666666664, 19.63064743814069)
# Case-19  Description Confidence       (56.18181818181818, 20.1910785665267)
#          EKG Confidence              (46.78260869565217, 22.72954929309408)
# dtype: object

# %%
mean_std_groupB.to_excel("Mean-Std-GroupB.xlsx")

# %%
def save_as_xlsx(users_dict, path, filename_p=""):
    
    filename = path + filename_p
    
    for user in users_dict.keys():
        
        filename += str(user) + ".xlsx"
        users_dict[user].to_excel(filename, index=False)
        filename = path + filename_p

# %%
def save_as_csv(users_dict, path, filename_p=""):
    
    filename = path + filename_p
    
    for user in users_dict.keys():
        
        filename += str(user) + ".csv"
        users_dict[user].to_csv(filename, index=False)
        filename = path + filename_p

# %%
path = "/home/marcosf/git/harena-analytics/resources/nl-experiment1/Tables/Group_DF/"
save_as_csv(groupA_clean, path)

# %%
path_B = "/home/marcosf/git/harena-analytics/resources/nl-experiment1/Tables/Group_EF/"
save_as_csv(groupB_clean, path_B)

# %% [markdown]
# # Add Physician correct answers to user track

# %%
correct_answers = pd.read_excel("correct_answers.xlsx", index_col=[0,1])

# %%
answer_case = groupA_beauti[81][groupA_beauti[81].Case == "Case-01"] 
pd.merge(answer_case, correct_answers['Points']['Case-01'], on="Answer", how="left")
# Out:
#                  Question Answer     Case  Points
# 0          EKG Hypothesis    acs  Case-01     1.0
# 1          EKG Confidence     48  Case-01     NaN
# 2  Description Hypothesis    acs  Case-01     1.0
# 3  Description Confidence     64  Case-01     NaN

# %%
correct_answers["Points"]["Case-07"]
# Out:
# Answer
# pericarditis                         1.0
# stemi                                0.0
# acs                                  0.0
# pericarditis / pleuritis             1.0
# tendomyogeen                         0.0
# stemi ipl                            0.0
# costo myogeen                        0.0
# inferoseptaal infarct                0.0
# acs, verdenking stemi ipl            0.0
# pericarditis of negroïde patiënt     1.0
# musculoskeletaal                     0.0
# st elevaties inferior en anterior    0.0
# pericaridits                         1.0
# costomyalgeen                        0.0
# Name: Points, dtype: float64

# %%
def user_answers_points(users_track, correct_answers):
    
    users_points = dict()
    cases_list = ["Case-01", "Case-02", "Case-03", "Case-07", "Case-08", "Case-09", "Case-12", "Case-13", "Case-15", "Case-16", "Case-17", "Case-19"]
    
    for user in users_track.keys():
        users_points[user] = pd.DataFrame(columns=["Question", "Answer", "Case", "Points"])
        
        for case in cases_list:
            answer_case = users_track[user][users_track[user].Case == case]
            points_case = pd.merge(answer_case, correct_answers['Points'][case], on="Answer", how="left")   
            users_points[user] = pd.concat([users_points[user], points_case], sort=False)
        
        users_points[user].sort_values(["Question", "Case"], ascending=False)
    return users_points

# %%
groupA_answers_points = user_answers_points(groupA_beauti, correct_answers)

# %%
groupB_answers_points = user_answers_points(groupB_beauti, correct_answers)

# %%
groupB_answers_points[113]
# Out:
#                  Question                                             Answer  \
# 0          EKG Hypothesis  inferolateraal negatieve ts en minimale st dep...
# 1          EKG Confidence                                                 74
# 2  Description Hypothesis  inferolateraal negatieve ts en minimale st dep...
# 3  Description Confidence                                                 63
# 0          EKG Hypothesis                   indien neg, vroege repolarisatie
# 1          EKG Confidence                                                 70
# 2  Description Hypothesis  nog steeds verdenking acs, opnieuw ecg maken o...
# 3  Description Confidence                                                 63
# 0          EKG Hypothesis                                          stemi ipl
# 1          EKG Confidence                                                 71
# 2  Description Hypothesis     vroege repolarisatie, acs nog niet uitgesloten
# 3  Description Confidence                                                 62
# 0          EKG Hypothesis                          acs, verdenking stemi ipl
# 1          EKG Confidence                                                 63
# 2  Description Hypothesis                                          stemi ipl
# 3  Description Confidence                                                 69
# 0          EKG Hypothesis  komvormige st depressie inferolateraal, kan pa...
# 1          EKG Confidence                                                 41
# 2  Description Hypothesis                                acs, cardiomypathie
# 3  Description Confidence                                                 59
# 0                     NaN                                                NaN
# 0                     NaN                                                NaN
# 0                     NaN                                                NaN
# 0                     NaN                                                NaN
# 0                     NaN                                                NaN
# 0                     NaN                                                NaN
# 0                     NaN                                                NaN
#
#       Case  Points
# 0  Case-01     0.5
# 1  Case-01     NaN
# 2  Case-01     0.5
# 3  Case-01     NaN
# 0  Case-02     0.0
# 1  Case-02     NaN
# 2  Case-02     0.0
# 3  Case-02     NaN
# 0  Case-03     0.0
# 1  Case-03     NaN
# 2  Case-03     1.0
# 3  Case-03     NaN
# 0  Case-07     0.0
# 1  Case-07     NaN
# 2  Case-07     0.0
# 3  Case-07     NaN
# 0  Case-08     0.0
# 1  Case-08     NaN
# 2  Case-08     1.0
# 3  Case-08     NaN
# 0  Case-09     NaN
# 0  Case-12     NaN
# 0  Case-13     NaN
# 0  Case-15     NaN
# 0  Case-16     NaN
# 0  Case-17     NaN
# 0  Case-19     NaN

# %%
path = "/home/marcosf/git/harena-analytics/resources/nl-experiment1/Tables/Group_DF/Points"
save_as_csv(groupA_answers_points, path)

# %%
path = "/home/marcosf/git/harena-analytics/resources/nl-experiment1/Tables/Group_EF/Points"
save_as_csv(groupB_answers_points, path)

# %% [markdown]
# # Time measures

# %%
def users_start_time(users_track):
    
    users_time = dict()
    
    for user in users_track.keys():
        users_time[user] = pd.DataFrame(columns=["Topic", "CaseId", "Time"])
        init_timestamp = None
        for log in users_track[user]:
            if "case/Case-01/navigate" in log['topic']:
                init_timestamp = log['timestamp']
            if re.search('knot/[\w+.]+/start', log['topic']):
                var_topic = re.search('knot/[\w+.]+/start', log['topic']).group()
                case_id = log['payload']['track']['caseid']
                elapsed_time = 0
                if init_timestamp is not None:
                    elapsed_time = log['timestamp'] - init_timestamp
                    elapsed_time = elapsed_time.total_seconds()
                row = {"Topic": var_topic, "CaseId": case_id, "Time": elapsed_time}
                users_time[user] = users_time[user].append(row, ignore_index=True)
                
    return users_time

# %%
def time_per_cycle(users_time_track, group_kind):
    
    users_time = dict()    
    for user in users_time_track.keys():
        users_time[user] = pd.DataFrame(columns=["Cycle", "Case", "Time"])
        
        grouped = users_time_track[user].groupby("Case")
        for name, group in grouped:
            
            if group_kind == "Description First":
                
                try:
                    case_final_start = group[group["Topic"] == "knot/Final.Report/start"]["Time"]
                    case_final_start_time = case_final_start.max()
                    ekg_start = group[group["Topic"] == "knot/EKG_Cycle.EKG/start"]["Time"]
                    ekg_start_time = ekg_start.where(ekg_start < case_final_start_time).max()
                    description_start = group[group["Topic"] == "knot/Description_Cycle.Description/start"]["Time"]
                    description_start_time = description_start.where(description_start < ekg_start_time).max()
                    
                except:
                    continue

                description_cycle_time = ekg_start_time - description_start_time 
                                           
                row = {"Cycle": "Description Cycle", "Case": name, "Time": description_cycle_time}
                users_time[user] = users_time[user].append(row, ignore_index=True)
                
                ekg_cycle_time = case_final_start_time - ekg_start_time
                
                row = {"Cycle": "EKG Cycle", "Case": name, "Time": ekg_cycle_time}
                users_time[user] = users_time[user].append(row, ignore_index=True)
            
            elif group_kind == "EKG First":
                
                try:
                    case_final_start = group[group["Topic"] == "knot/Final.Report/start"]["Time"]
                    case_final_start_time = case_final_start.max()
                    description_start = group[group["Topic"] == "knot/Description_Cycle.Description/start"]["Time"]
                    description_start_time = description_start.where(description_start < case_final_start_time).max()
                    ekg_start = group[group["Topic"] == "knot/EKG_Cycle.EKG/start"]["Time"]
                    ekg_start_time = ekg_start.where(ekg_start < description_start_time).max()
                    
    
                except:
                    continue
                
                ekg_cycle_time = description_start_time - ekg_start_time
                row = {"Cycle": "EKG Cycle", "Case": name, "Time": ekg_cycle_time}
                users_time[user] = users_time[user].append(row, ignore_index=True)
                
                description_cycle_time = case_final_start_time - description_start_time  
                row = {"Cycle": "Description Cycle", "Case": name, "Time": description_cycle_time}
                users_time[user] = users_time[user].append(row, ignore_index=True)
            
            else:
                print("Insert a valid group kind")
            
    return users_time

# %%
def beautify_case_name(users_track, cases_name, selected_columns):
    
    for user in users_track.keys():
        df_merged = pd.merge(users_track[user],cases_name, on="CaseId", how="inner")
        df_merged = df_merged[selected_columns]
        users_track[user] = df_merged
    
    return users_track

# %%
cases_dict = {"Case-01":"5c0cf92e-ebe3-4f83-bb3b-11846d0f3da8",
              "Case-02":"71cb08b0-aa66-402f-8d35-027e01bd541f",
              "Case-03":"1edff734-1090-4d44-bd52-963156b6b41d",
              "Case-07":"9c5b0ab8-33c8-4bcf-bcb4-d888327b870b",
              "Case-08":"28688ea2-f8d8-4664-80f6-0926720990fb",
              "Case-09":"ec4be4fd-4e48-4e84-ba8e-36c53b415698",
              "Case-12":"280fa4a7-1e79-4097-a961-7fda24d7d9bf",
              "Case-13":"7fbf35be-79fa-4087-94cd-ccc8030ac305",
              "Case-15":"a775bf21-b15c-44d1-a120-61611bc7960c",
              "Case-16":"b90056f9-e5e2-4281-bcfe-75ab62033b2b",
              "Case-17":"070e904b-fe21-4629-83b2-4f9ea49bccce",
              "Case-19":"64634e19-ea0a-4060-9656-1252b5d6acb5"
             }
cases_name = pd.DataFrame(cases_dict.items(), columns=["Case", "CaseId"])

# %%
users_time_groupA = users_start_time(group_A)
users_time_groupB = users_start_time(group_B)

# %%
users_time_groupA_b = beautify_case_name(users_time_groupA, cases_name, selected_columns=["Topic", "Case", "Time"])
users_time_groupB_b = beautify_case_name(users_time_groupB, cases_name, selected_columns=["Topic", "Case", "Time"])

# %%
time_cycle_groupA = time_per_cycle(users_time_groupA_b, "Description First")

# %%
time_cycle_groupA[61]
# Out:
#                 Cycle     Case     Time
# 0   Description Cycle  Case-01  116.289
# 1           EKG Cycle  Case-01   44.170
# 2   Description Cycle  Case-02  102.178
# 3           EKG Cycle  Case-02  101.369
# 4   Description Cycle  Case-03   81.420
# 5           EKG Cycle  Case-03   31.000
# 6   Description Cycle  Case-07   67.921
# 7           EKG Cycle  Case-07   34.735
# 8   Description Cycle  Case-08   49.271
# 9           EKG Cycle  Case-08   33.656
# 10  Description Cycle  Case-09   67.402
# 11          EKG Cycle  Case-09   36.093
# 12  Description Cycle  Case-12  148.743
# 13          EKG Cycle  Case-12   58.115
# 14  Description Cycle  Case-13   36.460
# 15          EKG Cycle  Case-13   37.142
# 16  Description Cycle  Case-15   43.973
# 17          EKG Cycle  Case-15   15.155
# 18  Description Cycle  Case-16   51.140
# 19          EKG Cycle  Case-16   23.694
# 20  Description Cycle  Case-17   81.189
# 21          EKG Cycle  Case-17   19.974
# 22  Description Cycle  Case-19   50.706
# 23          EKG Cycle  Case-19   24.215

# %%
time_cycle_groupA[61]
# Out:
#                 Cycle     Case     Time
# 0   Description Cycle  Case-01  116.289
# 1           EKG Cycle  Case-01   44.170
# 2   Description Cycle  Case-02  102.178
# 3           EKG Cycle  Case-02  101.369
# 4   Description Cycle  Case-03   81.420
# 5           EKG Cycle  Case-03   31.000
# 6   Description Cycle  Case-07   67.921
# 7           EKG Cycle  Case-07   34.735
# 8   Description Cycle  Case-08   49.271
# 9           EKG Cycle  Case-08   33.656
# 10  Description Cycle  Case-09   67.402
# 11          EKG Cycle  Case-09   36.093
# 12  Description Cycle  Case-12  148.743
# 13          EKG Cycle  Case-12   58.115
# 14  Description Cycle  Case-13   36.460
# 15          EKG Cycle  Case-13   37.142
# 16  Description Cycle  Case-15   43.973
# 17          EKG Cycle  Case-15   15.155
# 18  Description Cycle  Case-16   51.140
# 19          EKG Cycle  Case-16   23.694
# 20  Description Cycle  Case-17   81.189
# 21          EKG Cycle  Case-17   19.974
# 22  Description Cycle  Case-19   50.706
# 23          EKG Cycle  Case-19   24.215

# %%
time_cycle_groupB = time_per_cycle(users_time_groupB_b, "EKG First")

# %%
users_time_groupA_b[76][users_time_groupA_b[76]["Case"] == "Case-12"].sort_values("Time")
# Out:
#                                        Topic     Case     Time
# 43  knot/Description_Cycle.Description/start  Case-12  536.017

# %%
users_time_groupB_b[108][users_time_groupB_b[108]["Case"] == "Case-13"].sort_values("Time")
# Out:
#                                                Topic     Case     Time
# 46                          knot/EKG_Cycle.EKG/start  Case-13  912.683
# 47          knot/EKG_Cycle.Generate_hypothesis/start  Case-13  940.613
# 48          knot/Description_Cycle.Description/start  Case-13  991.375
# 49  knot/Description_Cycle.Generate_hypothesis/start  Case-13  991.851

# %%
time_cycle_groupB[86]
# Out:
#                 Cycle     Case     Time
# 0           EKG Cycle  Case-01   45.655
# 1   Description Cycle  Case-01  126.697
# 2           EKG Cycle  Case-02   29.424
# 3   Description Cycle  Case-02   79.996
# 4           EKG Cycle  Case-03   26.605
# 5   Description Cycle  Case-03   39.663
# 6           EKG Cycle  Case-07   24.479
# 7   Description Cycle  Case-07   55.284
# 8           EKG Cycle  Case-08   29.708
# 9   Description Cycle  Case-08   43.611
# 10          EKG Cycle  Case-09   89.988
# 11  Description Cycle  Case-09   33.166
# 12          EKG Cycle  Case-12   30.321
# 13  Description Cycle  Case-12   64.104
# 14          EKG Cycle  Case-13   60.701
# 15  Description Cycle  Case-13   26.110
# 16          EKG Cycle  Case-15   35.043
# 17  Description Cycle  Case-15   44.321
# 18          EKG Cycle  Case-16   58.735
# 19  Description Cycle  Case-16   31.337
# 20          EKG Cycle  Case-17   79.688
# 21  Description Cycle  Case-17   41.723
# 22          EKG Cycle  Case-19   53.026
# 23  Description Cycle  Case-19   41.635

# %%
path = "/home/marcosf/git/harena-analytics/resources/nl-experiment1/Tables/Group_DF/Time"
save_as_csv(time_cycle_groupA, path)

# %%
path = "/home/marcosf/git/harena-analytics/resources/nl-experiment1/Tables/Group_EF/Time"
save_as_csv(time_cycle_groupB, path)
